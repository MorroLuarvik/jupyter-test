# %%
CONFIG_FILE_NAME = 'config.json'
import os
import json

# %%
PAIR_ID = 18
query = "select * from s_trade_stats where pair_id = {0}".format(PAIR_ID)

# %%
params_file = open('../' + CONFIG_FILE_NAME, 'r+')
db_params = json.load(params_file)
params_file.close()

# %%
import MySQLdb
db_connection = MySQLdb.connect(**db_params)

# %%
import pandas
# %time data_source = pandas.read_sql_query(query, con=db_connection)
# Out:
# Wall time: 6.48 s

# %%
data_source.head()
# Out:
#    pair_id    start_ts      end_ts  cou  price_open  price_min  price_max  \
# 0       18  1504730700  1504730999    6    0.017472   0.017472   0.017547
# 1       18  1504731000  1504731299    2    0.017629   0.017629   0.017629
# 2       18  1504731600  1504731899    3    0.017629   0.017629   0.017629
# 3       18  1504731900  1504732199    1    0.017564   0.017564   0.017564
# 4       18  1504732200  1504732499   13    0.017564   0.017475   0.017700
#
#    price_close  amount_sum  amount_2_sum  price_sum  price_2_sum  volume_sum  \
# 0     0.017547   19.453324    310.550357   0.104907     0.001834    0.341206
# 1     0.017629    0.023235      0.000336   0.035259     0.000622    0.000410
# 2     0.017629    0.069420      0.002388   0.052888     0.000932    0.001224
# 3     0.017564    0.006325      0.000040   0.017564     0.000309    0.000111
# 4     0.017476    6.770686      7.405712   0.228644     0.004021    0.119388
#
#    volume_2_sum
# 0  9.561322e-02
# 1  1.000000e-07
# 2  7.400000e-07
# 3  1.000000e-08
# 4  2.303140e-03

# %%
data_source.tail()
# Out:
#         pair_id    start_ts      end_ts  cou  price_open  price_min  \
# 238339       18  1580774400  1580774699    2    0.007545   0.007543
# 238340       18  1580774700  1580774999    1    0.007557   0.007557
# 238341       18  1580775000  1580775299    1    0.007557   0.007557
# 238342       18  1580775600  1580775899    6    0.007556   0.007452
# 238343       18  1580775900  1580776199    2    0.007547   0.007547
#
#         price_max  price_close  amount_sum   amount_2_sum  price_sum  \
# 238339   0.007545     0.007543  327.989258   54289.361824   0.015088
# 238340   0.007557     0.007557  103.517998   10715.975856   0.007557
# 238341   0.007557     0.007557    0.022133       0.000490   0.007557
# 238342   0.007556     0.007452  423.483919   95438.699451   0.044919
# 238343   0.007549     0.007549  397.548008  116455.616376   0.015096
#
#         price_2_sum  volume_sum  volume_2_sum
# 238339     0.000114    2.474320  3.089540e+00
# 238340     0.000057    0.782310  6.120095e-01
# 238341     0.000057    0.000167  3.000000e-08
# 238342     0.000336    3.199315  5.448082e+00
# 238343     0.000114    3.000874  6.635941e+00
